# %%
"hello world"
# Out:
# 'hello world'

# %%
'hello'
# Out:
# 'hello'

# %%
print("hello")
# Out:
# hello

# %%
name='dilara'

# %%
type(name)
# Out:
# str

# %%
 name.capitalize()
# Out:
# 'Dilara'

# %%
name.casefold()
# Out:
# 'dilara'

# %%
name.isnumeric()
# Out:
# False

# %%
x=23

# %%
x.bit_count()
# Out:
# 4

# %%
x.to_bytes()
# Out:
# b'\x17'

# %%
x.bit_count()
# Out:
# 4

# %%
x.bit_length()
# Out:
# 5

# %%
help(name.count)
# Out:
# Help on built-in function count:
#
# count(...) method of builtins.str instance
#     S.count(sub[, start[, end]]) -> int
#
#     Return the number of non-overlapping occurrences of substring sub in
#     string S[start:end].  Optional arguments start and end are
#     interpreted as in slice notation.

# %%
name.count("a")
# Out:
# 2

# %%
name="Dilara"

# %%
name.count("A")
# Out:
# 0

# %%
surname="AKAY"

# %%
name+surname
# Out:
# 'DilaraAKAY'

# %%
nAndS=name+" "+surname

# %%
nAndS
# Out:
# 'Dilara AKAY'

# %%
print(name.upper())
# Out:
# DILARA

# %%
#return varsa yeni bir değişkene değeri atıyor demektir

# %%
len(name)
# Out:
# 6

# %%
print("Dilara \nAKAY")
# Out:
# Dilara
# AKAY

# %%
#\n new line aanlamına gelir
