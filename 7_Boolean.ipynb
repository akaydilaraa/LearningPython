# %%
#ya true ya false değeri alır

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
myBoolean=True

# %%
type(myBoolean)
# Out:
# bool

# %%
2<3
# Out:
# True

# %%
4>5
# Out:
# False

# %%
yas=input("Yasınız:")
int(yas)>18
# Out:
# Yasınız: 23
# True
