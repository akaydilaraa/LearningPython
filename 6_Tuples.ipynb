# %%
#neredeyse liste ile aynı şey

# %%
#listelerin ilk elemanını değiştirebiliyoruz ama stringlerin harflerini değiştiremiyoruz

# %%
myList=[10,"a",3.45]

# %%
myList[0]=90

# %%
myList
# Out:
# [90, 'a', 3.45]

# %%
myTuple=(10,23,"a")

# %%
myTuple
# Out:
# (10, 23, 'a')

# %%
type(myTuple)
# Out:
# tuple

# %%
#immutability özelliği sağlar

# %%
#myTuple[0]=10 yapamam mesela
