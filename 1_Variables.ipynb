# %%
4+3
# Out:
# 7

# %%
4*9
# Out:
# 36

# %%
50/3
# Out:
# 16.666666666666668

# %%
24/8
# Out:
# 3.0

# %% [markdown]
# Başlık nasıl atılır?

# %%
age = 23

# %%
age
# Out:
# 23

# %%
age*3
# Out:
# 69

# %%
age + 34
# Out:
# 57

# %%
age - 24
# Out:
# -1

# %%
 #veri tiplerini yazacağız yorum satırıdır bu

# %%
type
# Out:
# type

# %%
type
# Out:
# type

# %%
type
# Out:
# type

# %%
type(10)
# Out:
# int

# %%
type(10*3)
# Out:
# int

# %%
type(dilara)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 type(dilara)
#
# NameError: name 'dilara' is not defined

# %%
type(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 type(x)
#
# NameError: name 'x' is not defined

# %%
type("dilara")
# Out:
# str

# %%
x=10

# %%
x
# Out:
# 10

# %%
x=20;

# %%
x
# Out:
# 20

# %%
#x i istediğimiz yerde değiştirebildik

# %%
myFloat = 2.2344

# %%
myFloat
# Out:
# 2.2344

# %%
type(myFloat
    )
# Out:
# float
