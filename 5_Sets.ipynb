# %%
#içerisinde birden fazla değer tutabiliyor

# %%
#unique elements, unordered

# %%
#tekil elemanlar, sırası yok

# %%
myList=[10,20,30,40,50 ,10, 20 ,20 ,40]

# %%
len(myList)
# Out:
# 9

# %%
myList
# Out:
# [10, 20, 30, 40, 50, 10, 20, 20, 40]

# %%
mySet= set(myList)

# %%
mySet
# Out:
# {10, 20, 30, 40, 50}

# %%
#Aynı değerden sadece bir tane olacak

# %%
#set oluşturmak için

# %%
mySet={10,20,30,40,10,20,30}

# %%
mySet #istediğini ver o tekil hale çevirecek
# Out:
# {10, 20, 30, 40}

# %%
mySet.add(10) #eklemedi mesela çünkü var

# %%
mySet
# Out:
# {10, 20, 30, 40}

# %%
mySet.add(50)

# %%
mySet
# Out:
# {10, 20, 30, 40, 50}

# %%
#mySet[0] yapamıyoruz alamıyoruz ilk elemanı

# %%
#o şekilde alamadık ama birleştirme yapabiliriz

# %%
mySet
# Out:
# {10, 20, 30, 40, 50}

# %%
mySet2={20,80,60}

# %%
mySet.union(mySet2) #birleştirme
# Out:
# {10, 20, 30, 40, 50, 60, 80}

# %%
mySet.intersection(mySet2) #kesişimlerini aldı
# Out:
# {20}

# %%
#boş set oluşturmak istersek
#emptyset={} yaparsak bunu dict sanar

# %%
emptySet=set()

# %%
type(emptySet)
# Out:
# set

# %%
emptySet.add(10)
emptySet.add(20)
emptySet.add(20)
emptySet.add(30)

# %%
emptySet
# Out:
# {10, 20, 30}

# %%
emptyList=[]

# %%
type(emptyList)
# Out:
# list

# %%
emptyList2=list()

# %%
type(emptyList2)
# Out:
# list

# %%
#İki şekilde de dizi oluşturabiliriz

# %%
emptyList.append(10)

# %%
emptyList
# Out:
# [10]
