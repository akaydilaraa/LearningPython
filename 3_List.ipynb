# %%
myString="hello python"

# %%
myString.split()
# Out:
# ['hello', 'python']

# %%
type(myString.split())
# Out:
# list

# %%
#içerisinde birden çok içerik tutabilir

# %%
#myString[0]="a" yapamayız hata alırız immutable

# %%
#myString i tamamen değiştirebiliyoruz ama tek bir elemanını değiştiremiyoruz

# %%
myList=[10,20,30]

# %%
myList
# Out:
# [10, 20, 30]

# %%
type(myList)
# Out:
# list

# %%
x=10
y=20
z=30

# %%
myList=[x,y,z]

# %%
type(myList)
# Out:
# list

# %%
myList[0]
# Out:
# 10

# %%
myList[0]=100

# %%
myList
# Out:
# [100, 20, 30]

# %%
#Mutable

# %%
myList[-1]
# Out:
# 30

# %%
myList
# Out:
# [100, 20, 30]

# %%
myList.append(12)

# %%
myList
# Out:
# [100, 20, 30, 12]

# %%
myList.index(20)
# Out:
# 1

# %%
myList.append(20)

# %%
myList
# Out:
# [100, 20, 30, 12, 20]

# %%
myList.index(20) #İLK GÖRDÜĞÜ İNDEXİ
# Out:
# 1

# %%
#append sona ekliyor insert istediğin indexe

# %%
myList
# Out:
# [100, 20, 30, 12, 20]

# %%
myList.insert(1,45)

# %%
myList
# Out:
# [100, 45, 20, 30, 12, 20]

# %%
myList.pop() #son elemanı attı
# Out:
# 30

# %%
myList
# Out:
# [100, 20]

# %%
myList.remove(20)

# %%
myList
# Out:
# [100, 20]

# %%
myList
# Out:
# [100]

# %%
x=input("enter x")
# Out:
# enter x 23

# %%
x
# Out:
# '23'

# %%
#inputtan gelen her şey string

# %%
inputList=[]

# %%
inputList.append(x)

# %%
inputList
# Out:
# ['23']

# %%
inputList[0]
# Out:
# '23'

# %%
inputList[0] * 2
# Out:
# '2323'

# %%
#çarpma yapamadı çünkü bu string bir ifade

# %%
myInteger=50

# %%
str(myInteger)
# Out:
# '50'

# %%
mystr="12"

# %%
int(mystr)
# Out:
# 12

# %%
mystr*2
# Out:
# '1212'

# %%
int(mystr)*2
# Out:
# 24

# %%
list1=[10,20,30]

# %%
list2=[30,40,50]

# %%
list1+list2
# Out:
# [10, 20, 30, 30, 40, 50]

# %%
#string olarak gördüğü için yan yana yazdı birleştirme işlemi yaptı

# %%
mixList=[10,'dilara', 12.3]

# %%
type(mixList)
# Out:
# list

# %%
type(mixList[1])
# Out:
# str

# %%
#nestedList= iç içe geçmiş listeler

# %%
myNestedList=[12,'Dilara',[1,2,3]]

# %%
myNestedList[2]
# Out:
# [1, 2, 3]

# %%
x=myNestedList[2]

# %%
x[1]
# Out:
# 2

# %%
myNestedList[2][1] #liste içinde listeye ulaşmanın kolay yolu
# Out:
# 2
