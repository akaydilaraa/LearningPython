# %%
#key - value pairing anahtar değer eşleşmesi

# %%
fruit_list=["banana","apple"]

# %%
type(fruit_list)
# Out:
# list

# %%
calories=[100,150]

# %%
fruit_list[0]
# Out:
# 'banana'

# %%
calories[0]
# Out:
# 100

# %%
fitness_dictionary={"banana":100,"apple":150}

# %%
type(fitness_dictionary)
# Out:
# dict

# %%
#fitness_dictionary[0] böyle yapamayız artık index mantığı yok sadece anahtar değer eşlemesi mantığı

# %%
fitness_dictionary["banana"]
# Out:
# 100

# %%
fitness_dictionary.keys() #sadece anahtarları verir
# Out:
# dict_keys(['banana', 'apple'])

# %%
fitness_dictionary.values() #sadece değerleri verir
# Out:
# dict_values([100, 150])

# %%
#istersek bu değerleri listeye çevirebiliriz

# %%
list(fitness_dictionary.keys())
# Out:
# ['banana', 'apple']

# %%
#değiştirmek istersek bu da mümkün

# %%
fitness_dictionary["banana"]=200

# %%
fitness_dictionary
# Out:
# {'banana': 200, 'apple': 150}

# %%
#yenisini eklemek istersek

# %%
fitness_dictionary["melon"]=140

# %%
fitness_dictionary
# Out:
# {'banana': 200, 'apple': 150, 'melon': 140}

# %%
help(fitness_dictionary.get)
# Out:
# Help on built-in function get:
#
# get(key, default=None, /) method of builtins.dict instance
#     Return the value for key if key is in the dictionary, else default.

# %%
fitness_dictionary.get("apple",0)
# Out:
# 150

# %%
fitness_dictionary.get("appe",0)
# Out:
# 0

# %%
#olmayan bir key girdiğimizde hata vermek yerine verdiğimiz default değeri geriye dönderir

# %%
 #dictionary içerisine string koyabiliriz

# %%
last_dictionary={"k1":10,"k2":[10,20,30,40,50],"k3":{"a":100,"b":200}}

# %%
last_dictionary["k3"]["b"]
# Out:
# 200

# %%
last_dictionary["k2"][3]
# Out:
# 40
