# %%
x=5
y=2

# %%
x<y
# Out:
# False

# %%
x>y
# Out:
# True

# %%
x>= 5
# Out:
# True

# %%
#eşit mi kontrolü yapmak için

# %%
x==y
# Out:
# False

# %%
x!=y #eşit değil mi
# Out:
# True

# %%
2>1 and 3>2
# Out:
# True

# %%
True and False
# Out:
# False

# %%
2>1 or 4>1
# Out:
# True

# %%
not 1==1
# Out:
# False

# %%
10 in [10,20,30]
# Out:
# True

# %%
#in içerisinde var mı anlamı taşır

# %%
5 not in [10,20,30]
# Out:
# True

# %%
my_hero=input("Enter your hero")
# Out:
# Enter your hero Iron man

# %%
my_hero=="Batman"
# Out:
# False

# %%
if my_hero =="Batman":
    print("Doğru sonuç")

# %%
if my_hero=="Batman":
    print("Batmannn")

elif my_hero=="Superman":
    print("Superman")

else:
    print(":(")
# Out:
# :(

# %%
myage=45

# %%
if myage<=20:
    print("Genç")

elif myage >=20 and myage<55:
    print("Orta Yasli")

else:
    print("Yasli")
# Out:
# Orta Yasli

# %%
my_superhero= input("Enter superhero")
# Out:
# Enter superhero Iron Man

# %%
my_superhero_list=["Spider","Batman","Iron Man"]

# %%
if my_superhero in my_superhero_list:
    print("Listede var")

else:
    print("Listede yok")
# Out:
# Listede var
