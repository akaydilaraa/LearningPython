# %%
"hello world"
# Out:
# 'hello world'

# %%
'hello'
# Out:
# 'hello'

# %%
print("hello")
# Out:
# hello

# %%
name='dilara'

# %%
type(name)
# Out:
# str

# %%
 name.capitalize()
# Out:
# 'Dilara'

# %%
name.casefold()
# Out:
# 'dilara'

# %%
name.isnumeric()
# Out:
# False

# %%
x=23

# %%
x.bit_count()
# Out:
# 4

# %%
x.to_bytes()
# Out:
# b'\x17'

# %%
x.bit_count()
# Out:
# 4

# %%
x.bit_length()
# Out:
# 5

# %%
help(name.count)
# Out:
# Help on built-in function count:
#
# count(...) method of builtins.str instance
#     S.count(sub[, start[, end]]) -> int
#
#     Return the number of non-overlapping occurrences of substring sub in
#     string S[start:end].  Optional arguments start and end are
#     interpreted as in slice notation.

# %%
name.count("a")
# Out:
# 2

# %%
name="Dilara"

# %%
name.count("A")
# Out:
# 0

# %%
surname="AKAY"

# %%
name+surname
# Out:
# 'DilaraAKAY'

# %%
nAndS=name+" "+surname

# %%
nAndS
# Out:
# 'Dilara AKAY'

# %%
print(name.upper())
# Out:
# DILARA

# %%
#return varsa yeni bir değişkene değeri atıyor demektir

# %%
len(name)
# Out:
# 6

# %%
print("Dilara \nAKAY")
# Out:
# Dilara
# AKAY

# %%
#\n new line aanlamına gelir escape characters denir

# %% [markdown]
# INDEX

# %%
myString="hello python"

# %%
myString[4]
# Out:
# 'o'

# %%
myString[1]
# Out:
# 'e'

# %%
myString[11]
# Out:
# 'n'

# %%
myString[10]
# Out:
# 'o'

# %%
len(myString)
# Out:
# 12

# %%
myName="Dilara"

# %%
len(myName)
# Out:
# 6

# %%
myName[len(myName)-1]
# Out:
# 'a'

# %%
myName[-1]
# Out:
# 'a'

# %%
myName[-2]
# Out:
# 'r'

# %%
barcode="ABCDE1234567"

# %%
barcode[0]+ barcode[1]
# Out:
# 'AB'

# %%
#slicing, starting index, stopping index , stepping size

# %%
barcode="ABCD1234567"

# %%
#barcode[starting index : stopping index : stepping size]
#başlama indexi, bitiş indexi, kaçar kaçar gidileceği

# %%
barcode[3::] #3.indexten başla
# Out:
# 'D1234567'

# %%
barcode[:3:] #3.indexe kadar 3ü alma
# Out:
# 'ABC'

# %%
barcode[::2]
# Out:
# 'AC1357'

# %%
barcode[::5]
# Out:
# 'A27'

# %%
barcode[::]
# Out:
# 'ABCD1234567'

# %%
barcode[3:4:]
# Out:
# 'D'

# %%
barcode[3:5:]
# Out:
# 'D1'

# %%
barcode[::-1]  #Sondan başlatmak için
# Out:
# '7654321DCBA'
